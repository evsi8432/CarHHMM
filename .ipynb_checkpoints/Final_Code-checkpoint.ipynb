# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

from scipy.stats import gamma
from scipy.stats import norm
from scipy.stats import multivariate_normal
from scipy.stats import gaussian_kde
from scipy.special import expit
from scipy.special import logsumexp
from scipy.optimize import minimize
from scipy.optimize import LinearConstraint
from scipy.signal import convolve
from scipy.interpolate import interp1d

import divebomb

import time
import pickle

import importlib

# %%
import Preprocessor
import Parameters
import HHMM
import Visualisor

# %%
print(norm.rvs(0,1,1))
print(gamma.rvs(0.1,1,0.1,3))
# Out:
# [-0.88263037]
# [1.00016015 1.00314373 1.00000003]

# %%
pars = Parameters.Parameters()
prep = Preprocessor.Preprocessor(pars)

# %%
np.set_printoptions(suppress=True,precision=4)

# %%
HHMM_file = 'HHMM_deep_full'

# %% [markdown]
# # Preprocess Data

# %%
df = prep.load_data(pars.cvc_file,
                    pars.csv_file,
                    pars.cvc_cols)

df = prep.prune_cols(df)

df = prep.prune_times(df,
                      pars.stime,
                      pars.etime,
                      pars.drop_times)

df = prep.fix_pressure(df)

df = prep.find_Vz(df)

df = prep.smooth_columns(df,
                         pars.smoother,
                         pars.smooth_cols)

df,dive_df = prep.find_dives(df)

data = prep.get_all_features(df,dive_df)

viz = Visualisor.Visualisor(pars,data,df)
viz.lagplot(lims={'peak_jerk':[0,50],
                  'roll_at_pj':[0,1],
                  'heading_var':[0,0.2],
                  'FoVeDBA_low':[0,50],
                  'FoVeDBA_high':[0,10],
                  'Vz':[-5,5]})

# %% [markdown]
# # Train HHMM

# %%
s_dive = 72
e_dive = 81
deep_data = [data[i] for i in range(s_dive,e_dive)]

hhmm = HHMM.HHMM(pars,deep_data)
hhmm.likelihood(deep_data)

try:
    hhmm = hhmm.load(HHMM_file)
except:
    print('HHMM not found. Training new model')
    hhmm.train_DM(deep_data)
    hhmm.save(HHMM_file)
    
data0,df0 = hhmm.label_df(data,df)
# Out:
# /Users/evsi8432/Documents/Research/Whale_Research/Code/HHMM.py:368: RuntimeWarning:
#
# divide by zero encountered in log

# %% [markdown]
# # Visualize Results

# %%
hhmm.theta['dive_duration'] = {}
hhmm.theta['dive_duration']['mu'] = []

# %%
hhmm.generate_data(['dive_duration'],['FoVeDBA_low'])
# Out:
# {'max_depth': {'mu': array([1.5049, 4.0914]),
#   'sig': array([-0.2138,  3.3727]),
#   'corr': array([-4.7332, -8.429 ])},
#  'peak_jerk': {'mu': array([2.6096, 9.9727]),
#   'sig': array([ 1.1834, 22.8538]),
#   'corr': array([-0.3523,  0.0615])},
#  'roll_at_pj': {'mu': array([2.4753, 2.5596]),
#   'sig': array([48.6134, 45.6061]),
#   'corr': array([-2.1624, -6.9859])},
#  'heading_var': {'mu': array([0.0056, 0.084 ]),
#   'sig': array([0.0066, 0.1027]),
#   'corr': array([-0.383 , -6.5083])}}

# %%
viz.hhmm = hhmm
viz.plot_emission_probs()
viz.print_ptms()
viz.plot_dive_features(72,75,['depth','VeDBA','heading','roll','subdive_state_1_prob'],
                               ['max_depth','peak_jerk','heading_var'])
# Out:
# Probability transistion matrix for dive types:
# [[0.0051 0.9949]
#  [0.0001 0.9999]]
#
# Stationary distribution for dive types:
# [[0.0001 0.9999]]
#
#
#
#
# Probability transistion matrix for subdive behaviors, dive type 1:
# [[0.0002 0.9998]
#  [0.6395 0.3605]]
#
# Stationary Distribution for subdive behaviors, dive type 1:
# [[0.3901 0.6099]]
#
#
# Probability transistion matrix for subdive behaviors, dive type 2:
# [[0.9371 0.0629]
#  [0.3768 0.6232]]
#
# Stationary Distribution for subdive behaviors, dive type 2:
# [[0.857 0.143]]

# %% [markdown]
# # Things to note:
#
#     - Subdive states are much less sure than dive types
#     - Subdive states are more uncertain in shallow dives than deep dives
#         - should probably make different dstribtuions within different dive types
#     - VeDBA is very different within shallow dives compared to deep dives
#         - support for activity-specific use of energy readings

# %% [markdown]
# # Future Steps:
#
#     - Include other features (high-frequency VeDBA, roll, heading variance, peak jerk, etc.?)
#     - Use different subdive behaviors for different dive types
#     - Figure out what number of states in each level
#     - Write paper on fine-scale HHMMs and equivalence between correlated HMMs and continuous time models
