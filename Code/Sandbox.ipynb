# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib

from scipy.stats import gamma
from scipy.stats import norm
from scipy.stats import multivariate_normal
from scipy.stats import gaussian_kde
from scipy.special import expit
from scipy.special import logsumexp
from scipy.optimize import minimize
from scipy.optimize import LinearConstraint
from scipy.signal import convolve
from scipy.interpolate import interp1d

import divebomb

import time
import pickle

import importlib

matplotlib.rcParams.update({'font.size': 12})
#matplotlib.rcParams.update({'lines.markersize': 20})

np.random.seed(0)

# %%
csv_file = '../Data/Diary/20200822-170001-Gikumi_CC_130_001.csv'
df = pd.read_csv(csv_file,encoding='cp1252')
df['time'] = pd.to_datetime(df[' Date (local)']+' '+df[' Time (local)'],
                            format = "%d.%m.%Y %H:%M:%S.%f")

# %%
sind = 153000
eind = 154000

df[['time']+ycols].iloc[sind:eind:50].plot('time',ycols[0])
plt.ylim([15,-1])
plt.show()

for col in df.columns:
    
    try:
        df[['time',col]].iloc[sind:eind].plot('time',col)
        plt.show()
    except:
        pass

# %%
sind = 140000
eind = 150000

df[['time']+ycols].iloc[::50].plot('time',ycols[0])
plt.ylim([150,-1])
plt.show()

for col in df.columns:
    
    try:
        df[['time',col]].iloc[sind:eind:50].plot('time',col)
        plt.show()
    except:
        pass

# %%
len(df)
# Out:
# 1548834
