# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib
matplotlib.rcParams.update({'font.size': 16})
matplotlib.rcParams.update({'lines.markersize': 10})

from scipy.stats import gamma
from scipy.stats import norm
from scipy.stats import multivariate_normal
from scipy.stats import gaussian_kde
from scipy.special import expit
from scipy.special import logit
from scipy.special import logsumexp
from scipy.optimize import minimize
from scipy.optimize import LinearConstraint
from scipy.signal import convolve
from scipy.interpolate import interp1d

from copy import deepcopy

import divebomb

import time
import pickle

import importlib

np.random.seed(0)

import Preprocessor
import Parameters
import HHMM
import Visualisor

# %% [markdown]
# # Load in the HMMs

# %%
hhmms = []
for dataset_num in range(1,500):
    try:
        file = '../Params/hhmm_FV_%d_%d'%(0,dataset_num)
        with open(file, 'rb') as f:
            hhmm = pickle.load(f)
        A = hhmm.SEs
        hhmms.append(hhmm)
    except:
        print('../Params/hhmm_FV_%d_%d'%(0,dataset_num))
# Out:
# ../Params/hhmm_FV_0_56
# ../Params/hhmm_FV_0_80
# ../Params/hhmm_FV_0_99
# ../Params/hhmm_FV_0_102
# ../Params/hhmm_FV_0_176
# ../Params/hhmm_FV_0_218
# ../Params/hhmm_FV_0_293
# ../Params/hhmm_FV_0_302
# ../Params/hhmm_FV_0_374
# ../Params/hhmm_FV_0_399
# ../Params/hhmm_FV_0_417
# ../Params/hhmm_FV_0_424
# ../Params/hhmm_FV_0_430

# %% [markdown]
# # Plot Empirical distribtuion
#  - Compare with Fischer SEs

# %%
def make_2d_kde_theta(feature,theta0,hhmms,dive_type,N,include_corr=False):
    
    if dive_type == -1:
        theta = hhmm.theta[0]
    else:
        theta = hhmm.theta[1][dive_type]
    
    # get mu and sigma and corr
    if dive_type == -1:
        mus = np.array([hhmm.theta[0][feature]['mu'] for hhmm in hhmms])
        mus_SE = np.array([hhmm.SEs[feature]['mu'] for hhmm in hhmms])

        sigs = np.array([hhmm.theta[0][feature]['sig'] for hhmm in hhmms])
        sigs_SE = np.array([hhmm.SEs[feature]['sig'] for hhmm in hhmms])

        corrs = expit(np.array([hhmm.theta[0][feature]['corr'] for hhmm in hhmms]))
        corrs_SE = np.array([hhmm.SEs[feature]['corr'] for hhmm in hhmms])
    
    else:
        mus = np.array([hhmm.theta[1][dive_type][feature]['mu'] for hhmm in hhmms])
        mus_SE = np.array([hhmm.SEs[feature]['mu'] for hhmm in hhmms])

        sigs = np.array([hhmm.theta[1][dive_type][feature]['sig'] for hhmm in hhmms])
        sigs_SE = np.array([hhmm.SEs[feature]['sig'] for hhmm in hhmms])

        corrs = expit(np.array([hhmm.theta[1][dive_type][feature]['corr'] for hhmm in hhmms]))
        corrs_SE = np.array([hhmm.SEs[feature]['corr'] for hhmm in hhmms])
    
    # get a 2-D histogram of these guys
    for i in range(N):

        xlim = [np.mean(mus[:,i])-3*np.std(mus[:,i]),np.mean(mus[:,i])+3*np.std(mus[:,i])]
        ylim = [np.mean(sigs[:,i])-3*np.std(sigs[:,i]),np.mean(sigs[:,i])+3*np.std(sigs[:,i])]
        zlim = [np.mean(corrs[:,i])-3*np.std(corrs[:,i]),np.mean(corrs[:,i])+3*np.std(corrs[:,i])]
        
        if include_corr:
            fig, axs = plt.subplots(2,2,figsize = (10,10))

            plt.subplot(2,2,1)
            kernel = gaussian_kde([mus[:,i],corrs[:,i]])
            Xtemp, Ytemp = np.mgrid[xlim[0]:xlim[1]:100j,zlim[0]:zlim[1]:100j]
            positions = np.vstack([Xtemp.ravel(), Ytemp.ravel()])
            Ztemp = np.reshape(kernel.pdf(positions).T, Xtemp.shape)
            plt.imshow(np.rot90(Ztemp),extent = xlim + zlim, aspect='auto')
            plt.plot(theta0['mu'][i],theta0['corr'][i],'r*')
            c = plt.colorbar()
            c.set_label('Probability Density',fontsize = 16)
            plt.xticks([])
            plt.ylabel(r'$\rho$')

            fig.delaxes(axs[0,1])

            plt.subplot(2,2,3)
            kernel = gaussian_kde([mus[:,i],sigs[:,i]])
            Xtemp, Ytemp = np.mgrid[xlim[0]:xlim[1]:100j,ylim[0]:ylim[1]:100j]
            positions = np.vstack([Xtemp.ravel(), Ytemp.ravel()])
            Ztemp = np.reshape(kernel.pdf(positions).T, Xtemp.shape)
            plt.imshow(np.rot90(Ztemp),extent = xlim + ylim, aspect='auto')
            plt.plot(theta0['mu'][i],theta0['sig'][i],'r*')
            c = plt.colorbar()
            plt.xlabel(r'$\mu$')
            plt.ylabel(r'$\sigma$')
            
            plt.subplot(2,2,4)
            kernel = gaussian_kde([corrs[:,i],sigs[:,i]])
            Xtemp, Ytemp = np.mgrid[zlim[0]:zlim[1]:100j,ylim[0]:ylim[1]:100j]
            positions = np.vstack([Xtemp.ravel(), Ytemp.ravel()])
            Ztemp = np.reshape(kernel.pdf(positions).T, Xtemp.shape)
            plt.imshow(np.rot90(Ztemp),extent = zlim + ylim, aspect='auto')
            plt.plot(theta0['corr'][i],theta0['sig'][i],'r*')
            c = plt.colorbar()
            c.set_label('Probability Density',fontsize = 16)
            plt.xlabel(r'$\rho$')
            plt.yticks([])

            
        else:
            
            kernel = gaussian_kde([mus[:,i],sigs[:,i]])
            Xtemp, Ytemp = np.mgrid[xlim[0]:xlim[1]:100j,ylim[0]:ylim[1]:100j]
            positions = np.vstack([Xtemp.ravel(), Ytemp.ravel()])
            Ztemp = np.reshape(kernel.pdf(positions).T, Xtemp.shape)
            plt.imshow(np.rot90(Ztemp),extent = xlim + ylim, aspect='auto')
            plt.plot(theta0['mu'][i],theta0['sig'][i],'r*')
            c = plt.colorbar()
            c.set_label('Probability Density',fontsize = 16)
            plt.xlabel(r'$\mu$',fontsize=16)
            plt.ylabel(r'$\sigma$')
        
        plt.show()
        
    print(r'$\mu$ sample mean:', np.mean(mus,0))
    print('Bias:', np.mean(mus,0) - np.array(theta0['mu']))
    print('Empirical Standard Error:', np.std(mus,0))
    print('Fischer Standard Error:',np.nanmedian(mus_SE,0))
    print('pm:',np.std(mus_SE,0))
    print('')

    print(r'$\sigma$ sample mean:', np.mean(sigs,0))
    print('Bias:', np.mean(sigs,0) - np.array(theta0['sig']))
    print('Empirical Standard Error:', np.std(sigs,0))
    print('Fischer Standard Error:',np.nanmedian(sigs_SE,0))
    print('pm:',np.std(sigs_SE,0))
    print('')

    if include_corr:
        print(r'$\rho$ sample mean:', np.mean(corrs,0))
        print('Bias:', np.mean(corrs,0) - np.array(theta0['corr']))
        print('Empirical Standard Error:', np.std(corrs,0))
        print('Fischer Standard Error:',np.nanmedian(corrs_SE,0))
        print('pm:',np.std(corrs_SE,0))
        print('')
        
    return


def make_2d_kde_gamma(G0,hhmms):
    
    Gs = []
    SEs = []
    for hhmm in hhmms:
        ptm = HHMM.eta_2_ptm(hhmm.eta[0])
        SE = hhmm.SEs['Gamma_coarse']
        Gs.append(np.array([ptm[0,1],ptm[1,0]]))
        SEs.append(np.array([SE[0,1],SE[1,0]]))

    Gs = np.array(Gs)
    
    xlim = [np.mean(Gs[:,0])-3*np.std(Gs[:,0]),np.mean(Gs[:,0])+3*np.std(Gs[:,0])]
    ylim = [np.mean(Gs[:,1])-3*np.std(Gs[:,1]),np.mean(Gs[:,1])+3*np.std(Gs[:,1])]
    
    kernel = gaussian_kde([Gs[:,0],Gs[:,1]])
    Xtemp, Ytemp = np.mgrid[xlim[0]:xlim[1]:100j,ylim[0]:ylim[1]:100j]
    positions = np.vstack([Xtemp.ravel(), Ytemp.ravel()])
    Ztemp = np.reshape(kernel.pdf(positions).T, Xtemp.shape)
    plt.imshow(np.rot90(Ztemp),extent = xlim + ylim, aspect='auto')
    plt.plot(G0[0],G0[1],'r*')
    c = plt.colorbar()
    c.set_label('Probability Density')
    plt.xlabel('$\Gamma_{12}$')
    plt.ylabel('$\Gamma_{21}$')
    plt.show()

    print('Sample Mean:', np.mean(Gs,0))
    print('Bias:', np.mean(Gs,0) - G0)
    print('Empirical Standard Error: \n', np.std(Gs,0))
    print('Fischer Standard Error: \n', np.mean(SEs,0))
    print('pm:', np.std(SEs,0))
    
    return

# Gamma Coarse
G0 = [0.5,0.5]
make_2d_kde_gamma(G0,hhmms)
'''
# dive duration
theta0 = {'mu':[20,80],'sig':[5,50],'corr':[0,0]}
dive_type = -1
N = 2
make_2d_kde_theta('dive_duration',theta0,hhmms,dive_type,N,include_corr=False)

# acceleration
theta0 = {'mu':[0,0],'sig':[0.05,0.1],'corr':[0.99,0.95]}
dive_type = 0
make_2d_kde_theta('A',theta0,hhmms,dive_type,N,include_corr=True)

# FoVeDBA
F_mus0 = np.array([sum([5.0/n for n in range(2,12)]),
                   300 + sum([5.0/n for n in range(4,12)])])
F_sigs0 = np.sqrt(F_mus0)
theta0 = {'mu':F_mus0,'sig':F_sigs0,'corr':[0,0]}
dive_type = 0
make_2d_kde_theta('FoVeDBA',theta0,hhmms,dive_type,N,include_corr=False)
'''
# Out:
# Sample Mean: [0.50146153 0.49375703]
# Bias: [ 0.00146153 -0.00624297]
# Empirical Standard Error:
#  [0.02659147 0.0264809 ]
# Fischer Standard Error:
#  [0.07876828 0.07869274]
# pm: [0.00779914 0.00493418]
# "\n# dive duration\ntheta0 = {'mu':[20,80],'sig':[5,50],'corr':[0,0]}\ndive_type = -1\nN = 2\nmake_2d_kde_theta('dive_duration',theta0,hhmms,dive_type,N,include_corr=False)\n\n# acceleration\ntheta0 = {'mu':[0,0],'sig':[0.05,0.1],'corr':[0.99,0.95]}\ndive_type = 0\nmake_2d_kde_theta('A',theta0,hhmms,dive_type,N,include_corr=True)\n\n# FoVeDBA\nF_mus0 = np.array([sum([5.0/n for n in range(2,12)]),\n                   300 + sum([5.0/n for n in range(4,12)])])\nF_sigs0 = np.sqrt(F_mus0)\ntheta0 = {'mu':F_mus0,'sig':F_sigs0,'corr':[0,0]}\ndive_type = 0\nmake_2d_kde_theta('FoVeDBA',theta0,hhmms,dive_type,N,include_corr=False)\n"

# %%
# Do Gamma Coarse
try:
    G0 = [0.5,0.5]
    Gs = []
    SEs = []
    for hhmm in hhmms:
        ptm = HHMM.eta_2_ptm(hhmm.eta[0])
        SE = hhmm.SEs['Gamma_coarse']
        Gs.append(np.array([ptm[0,1],ptm[1,0]]))
        SEs.append(np.array([SE[0,1],SE[1,0]]))

    Gs = np.array(Gs)
    plt.hist(Gs[:,0])
    plt.axvline(G0[0],color='k',alpha=0.5,linestyle = '--')
    plt.hist(Gs[:,1])
    plt.axvline(G0[1],color='k',alpha=0.5,linestyle = '--')
    plt.show()

    print('Sample Mean:', np.mean(Gs,0))
    print('Bias:', np.mean(Gs,0) - G0)
    print('Empirical Standard Error: \n', np.std(Gs,0))
    print('Fischer Standard Error: \n', np.mean(SEs,0))
    print('pm:', np.std(SEs,0))
    
    G0 = [0.5,0.1]
except:
    G0 = [0.0,1.0]

# Then do Gamma fine 1
Gs = []
SEs = []
for hhmm in hhmms:
    ptm = HHMM.eta_2_ptm(hhmm.eta[1][0])
    SE = hhmm.SEs['Gamma_fine'][0]
    Gs.append(np.array([ptm[0,1],ptm[1,0]]))
    SEs.append(np.array([SE[0,1],SE[1,0]]))
    
Gs = np.array(Gs)
plt.hist(Gs[:,0])
plt.axvline(G0[0],color='k',alpha=0.5,linestyle = '--')
plt.hist(Gs[:,1])
plt.axvline(G0[1],color='k',alpha=0.5,linestyle = '--')
plt.show()
print('Sample Mean:', np.mean(Gs,0))
print('Bias:', np.mean(Gs,0) - G0)
print('Empirical Standard Error: \n', np.std(Gs,0))
print('Fischer Standard Error: \n', np.mean(SEs,0))
print('pm:', np.std(SEs,0))

# Then do Gamma fine 2
try:
    G0 = [0.2,0.3]
    Gs = []
    SEs = []
    for hhmm in hhmms:
        ptm = HHMM.eta_2_ptm(hhmm.eta[1][1])
        SE = hhmm.SEs['Gamma_fine'][1]
        Gs.append(np.array([ptm[0,1],ptm[1,0]]))
        SEs.append(np.array([SE[0,1],SE[1,0]]))

    Gs = np.array(Gs)
    plt.hist(Gs[:,0])
    plt.axvline(G0[0],color='k',alpha=0.5,linestyle = '--')
    plt.hist(Gs[:,1])
    plt.axvline(G0[1],color='k',alpha=0.5,linestyle = '--')
    plt.show()
    print('Sample Mean:', np.mean(Gs,0))
    print('Bias:', np.mean(Gs,0) - G0)
    print('Empirical Standard Error: \n', np.std(Gs,0))
    print('Fischer Standard Error: \n', np.mean(SEs,0))
    print('pm:', np.std(SEs,0))
except:
    pass
# Out:
# Sample Mean: [0.50146153 0.49375703]
# Bias: [ 0.00146153 -0.00624297]
# Empirical Standard Error:
#  [0.02659147 0.0264809 ]
# Fischer Standard Error:
#  [0.07876828 0.07869274]
# pm: [0.00779914 0.00493418]
# Sample Mean: [0.50000986 0.10017757]
# Bias: [9.86196486e-06 1.77568308e-04]
# Empirical Standard Error:
#  [0.00021273 0.0162259 ]
# Fischer Standard Error:
#  [0.0704983  0.01573735]
# pm: [0.01214406 0.00187558]
# Sample Mean: [0.20000762 0.29938365]
# Bias: [ 7.62493748e-06 -6.16346870e-04]
# Empirical Standard Error:
#  [0.01183112 0.01863663]
# Fischer Standard Error:
#  [0.01175577 0.01663624]
# pm: [0.00096401 0.00139343]

# %%
# first do dive duration
dd_mus = np.array([hhmm.theta[0]['dive_duration']['mu'] for hhmm in hhmms])
mus_SE = np.array([hhmm.SEs['dive_duration']['mu'] for hhmm in hhmms])

dd_sigs = np.array([hhmm.theta[0]['dive_duration']['sig'] for hhmm in hhmms])
sigs_SE = np.array([hhmm.SEs['dive_duration']['sig'] for hhmm in hhmms])

plt.hist(dd_mus[:,0])
plt.title('Dive Duration mu Histogram')
plt.axvline(20,color='k',alpha=0.5,linestyle = '--')
try:
    plt.hist(dd_mus[:,1])
except:
    pass
plt.axvline(80,color='k',alpha=0.5,linestyle = '--')
plt.show()
print('Sample Mean:', np.mean(dd_mus,0))
print('Bias:', np.mean(dd_mus,0) - np.array([20,80]))
print('Empirical Standard Error:', np.std(dd_mus,0))
print('Fischer Standard Error:',np.nanmedian(mus_SE,0))
print('pm:',np.std(mus_SE,0))

plt.hist(dd_sigs[:,0])
plt.title('Dive Duration sigma Histogram')
plt.axvline(5,color='k',alpha=0.5,linestyle = '--')
try:
    plt.hist(dd_sigs[:,1])
except:
    pass
plt.axvline(50,color='k',alpha=0.5,linestyle = '--')
plt.show()
print('Sample Mean:', np.mean(dd_sigs,0))
print('Bias:', np.mean(dd_sigs,0) - np.array([5,50]))
print('Empirical Standard Error:', np.std(dd_sigs,0))
print('Fischer Standard Error:',np.nanmedian(sigs_SE,0))
print('pm:',np.std(sigs_SE,0))


for i in range(2):
    xlim = [np.mean(dd_mus[:,i])-3*np.std(dd_mus[:,i]),np.mean(dd_mus[:,i])+3*np.std(dd_mus[:,i])]
    ylim = [np.mean(dd_sigs[:,i])-3*np.std(dd_sigs[:,i]),np.mean(dd_sigs[:,i])+3*np.std(dd_sigs[:,i])]
    kernel = gaussian_kde([dd_mus[:,i],dd_sigs[:,i]])
    Xtemp, Ytemp = np.mgrid[xlim[0]:xlim[1]:100j,ylim[0]:ylim[1]:100j]
    positions = np.vstack([Xtemp.ravel(), Ytemp.ravel()])
    Ztemp = np.reshape(kernel.pdf(positions).T, Xtemp.shape)
    plt.imshow(np.rot90(Ztemp),extent = xlim + ylim)
    plt.show()

# Then do Z1
A_mus = np.array([hhmm.theta[1][0]['A']['mu'] for hhmm in hhmms])
mus_SE = np.array([hhmm.SEs['A']['mu'] for hhmm in hhmms])

A_sigs = np.array([hhmm.theta[1][0]['A']['sig'] for hhmm in hhmms])
sigs_SE = np.array([hhmm.SEs['A']['sig'] for hhmm in hhmms])

A_corrs = np.array([expit(hhmm.theta[1][0]['A']['corr']) for hhmm in hhmms])
corrs_SE = np.array([hhmm.SEs['A']['corr'] for hhmm in hhmms])

plt.hist(A_mus[:,0])
plt.title('Acceleration mu Histogram')
plt.axvline(0,color='k',alpha=0.5,linestyle = '--')
try:
    plt.hist(A_mus[:,1])
except:
    pass
plt.axvline(0,color='k',alpha=0.5,linestyle = '--')
plt.show()
print('Sample Mean:', np.mean(A_mus,0))
print('Bias:', np.mean(A_mus,0))
print('Empirical Standard Error:',np.std(A_mus,0))
print('Fischer Standard Error:',np.nanmedian(mus_SE,0))
print('pm:',np.std(mus_SE,0))

plt.hist(A_sigs[:,0])
plt.title('Acceleration sigma Histogram')
plt.axvline(0.05,color='k',alpha=0.5,linestyle = '--')
try:
    plt.hist(A_sigs[:,1])
except:
    pass
plt.axvline(0.1,color='k',alpha=0.5,linestyle = '--')
plt.show()
print('Sample Mean:', np.mean(A_sigs,0))
print('Bias:', np.mean(A_sigs,0) - np.array([0.05,0.1]))
print('Empirical Standard Error:', np.std(A_sigs,0))
print('Fischer Standard Error:',np.nanmedian(sigs_SE,0))
print('pm:',np.std(sigs_SE,0))

plt.hist(A_corrs[:,0])
plt.title('Acceleration correlation Histogram')
plt.axvline(0.99,color='k',alpha=0.5,linestyle = '--')
try:
    plt.hist(A_corrs[:,1])
except:
    pass
plt.axvline(0.95,color='k',alpha=0.5,linestyle = '--')
plt.show()
print('Sample Mean:', np.mean(A_corrs,0))
print('Bias:', np.mean(A_corrs,0) - np.array([0.99,0.95]))
print('Empirical Standard Error:', np.std(A_corrs,0))
print('Fischer Standard Error:',np.nanmedian(corrs_SE,0))
print('pm:',np.std(corrs_SE,0))

for i in range(2):
    xlim = [np.mean(A_sigs[:,i])-3*np.std(A_sigs[:,i]),np.mean(A_sigs[:,i])+3*np.std(A_sigs[:,i])]
    ylim = [np.mean(A_corrs[:,i])-3*np.std(A_corrs[:,i]),np.mean(A_corrs[:,i])+3*np.std(A_corrs[:,i])]
    kernel = gaussian_kde([A_sigs[:,i],A_corrs[:,i]])
    Xtemp, Ytemp = np.mgrid[xlim[0]:xlim[1]:100j,ylim[0]:ylim[1]:100j]
    positions = np.vstack([Xtemp.ravel(), Ytemp.ravel()])
    Ztemp = np.reshape(kernel.pdf(positions).T, Xtemp.shape)
    plt.imshow(np.rot90(Ztemp),extent = xlim + ylim, aspect="auto")
    plt.show()

try:
    # Then do Z2
    F_mus0 = np.array([sum([5.0/n for n in range(2,12)]),
                       300 + sum([5.0/n for n in range(4,12)])])
    F_sigs0 = np.sqrt(F_mus0)

    F_mus = np.array([hhmm.theta[1][0]['FoVeDBA']['mu'] for hhmm in hhmms])
    mus_SE = np.array([hhmm.SEs['FoVeDBA']['mu'] for hhmm in hhmms])
    F_sigs = np.array([hhmm.theta[1][0]['FoVeDBA']['sig'] for hhmm in hhmms])
    sigs_SE = np.array([hhmm.SEs['FoVeDBA']['sig'] for hhmm in hhmms])

    plt.hist(F_mus[:,0])
    plt.title('FoVeDBA mu Histogram')
    plt.axvline(F_mus0[0],color='k',alpha=0.5,linestyle = '--')
    try:
        plt.hist(F_mus[:,1])
    except:
        pass
    plt.axvline(F_mus0[1],color='k',alpha=0.5,linestyle = '--')
    plt.show()
    print('Sample Mean:', np.mean(F_mus,0))
    print('Bias:', np.mean(F_mus,0) - F_mus0)
    print('Empirical Standard Error:', np.std(F_mus,0))
    print('Fischer Standard Error:',np.nanmedian(mus_SE,0))
    print('pm:',np.std(mus_SE,0))

    plt.hist(F_sigs[:,0])
    plt.title('FoVeDBA sigma Histogram')
    plt.axvline(F_sigs0[0],color='k',alpha=0.5,linestyle = '--')
    try:
        plt.hist(F_sigs[:,1])
    except:
        pass
    plt.axvline(F_sigs0[1],color='k',alpha=0.5,linestyle = '--')
    plt.show()
    print('Sample Mean:', np.mean(F_sigs,0))
    print('Bias:', np.mean(F_sigs,0) - F_sigs0)
    print('Empirical Standard Error:', np.std(F_sigs,0))
    print('Fischer Standard Error:',np.nanmedian(sigs_SE,0))
    print('pm:',np.std(sigs_SE,0))
except:
    pass
# Out:
# Sample Mean: [20.04959575 79.7042861 ]
# Bias: [ 0.04959575 -0.2957139 ]
# Empirical Standard Error: [1.55226694 8.26570239]
# Fischer Standard Error: [0.68602388 5.82639465]
# pm: [0.08679632 0.83672132]
# Sample Mean: [ 4.87807912 48.60761018]
# Bias: [-0.12192088 -1.39238982]
# Empirical Standard Error: [0.62325131 6.50258285]
# Fischer Standard Error: [0.53414287 5.12749568]
# pm: [0.07855271 0.75900809]
# Sample Mean: [0.00277094 0.00576977]
# Bias: [0.00277094 0.00576977]
# Empirical Standard Error: [0.04386012 0.03235118]
# Fischer Standard Error: [0.1307395  0.05582752]
# pm: [      nan 0.0162801]
# Sample Mean: [0.04923418 0.09723943]
# Bias: [-0.00076582 -0.00276057]
# Empirical Standard Error: [0.00101799 0.00202518]
# Fischer Standard Error: [0.00098264 0.00199928]
# pm: [6.69787941e-05 8.55914348e-05]
# Sample Mean: [0.98888013 0.94851593]
# Bias: [-0.00111987 -0.00148407]
# Empirical Standard Error: [0.00609349 0.0129832 ]
# Fischer Standard Error: [0.03470494 0.02742196]
# pm: [       nan 0.00362528]
# Sample Mean: [ 10.09918839 305.96852036]
# Bias: [-0.00019834  0.0358003 ]
# Empirical Standard Error: [0.09404206 0.53876352]
# Fischer Standard Error: [0.35660379 0.89019066]
# pm: [0.04794569 0.06967896]
# Sample Mean: [ 3.17785618 17.45793339]
# Bias: [-9.70454588e-05 -3.29991189e-02]
# Empirical Standard Error: [0.07041115 0.35813218]
# Fischer Standard Error: [0.27529649 0.63469112]
# pm: [0.05381048 0.05642657]

# %% [markdown]
# # Get percentage of time in right dive and subdive states

# %%
def acc(CM):
    return (CM[0,0]+CM[1,1])/np.sum(CM)

# get coarse accuracy
accuracies_coarse = [acc(hhmm.CM[0]) for hhmm in hhmms]
plt.hist(accuracies_coarse)
plt.show()
print(np.mean(accuracies_coarse))
print(np.std(accuracies_coarse))

accuracies_fine0 = [acc(hhmm.CM[1][0]) for hhmm in hhmms]
plt.hist(accuracies_fine0)
plt.show()
print(np.mean(accuracies_fine0))
print(np.std(accuracies_fine0))

accuracies_fine1 = [acc(hhmm.CM[1][1]) for hhmm in hhmms]
plt.hist(accuracies_fine1)
plt.show()
print(np.mean(accuracies_fine1))
print(np.std(accuracies_fine1))

# %% [markdown]
# # Get time to train

# %%
times = [hhmm.train_time for hhmm in hhmms]
plt.hist(times)
plt.title('Training Times')
plt.xlabel('Seconds')
print(np.mean(times))
print(np.std(times))
